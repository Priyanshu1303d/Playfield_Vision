# %%
from ultralytics import YOLO

#load the model
name_of_the_model = 'yolov8m.pt'
model = YOLO(name_of_the_model)

# %%
# %pwd
# Out:
# 'd:\\Projects\\Playfield_Vision\\research'

# %%
import os 
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\Projects\\Playfield_Vision'

# %%
import shutil
from pathlib import Path
location = Path('research\\', name_of_the_model)

print(location)

shutil.move(location,
            "models/"
            )
# Out:
# research\yolov8m.pt
# 'models/yolov8m.pt'

# %%
results = model.predict(
    source='Input_Videos/B1606b0e6_1_17.mp4',
    save=True,
    project='output_videos',
    name='yolo_test',
    exist_ok=True
)

print(results[0])
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) d:\Projects\Playfield_Vision\Input_Videos\B1606b0e6_1_17.mp4: 384x640 25 persons, 1 sports ball, 70.5ms
# video 1/1 (frame 2/750) d:\Projects\Playfield_Vision\Input_Videos\B1606b0e6_1_17.mp4: 384x640 26 persons, 1 sports ball, 29.5ms
# video 1/1 (frame 3/750) d:\Projects\Playfield_Vision\Input_Videos\B1606b0e6_1_17.mp4: 384x640 26 persons, 28.7ms
# ...

# %%
print("--------------------------------")
for box in results[0].boxes:
    print(box)
# Out:
# --------------------------------
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.8472], device='cuda:0')
# data: tensor([[1.5982e+03, 7.6974e+02, 1.6450e+03, 8.5908e+02, 8.4724e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1621.5886,  814.4075,   46.7314,   89.3423]], device='cuda:0')
# xywhn: tensor([[0.8446, 0.7541, 0.0243, 0.0827]], device='cuda:0')
# xyxy: tensor([[1598.2229,  769.7363, 1644.9543,  859.0786]], device='cuda:0')
# xyxyn: tensor([[0.8324, 0.7127, 0.8567, 0.7954]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.8318], device='cuda:0')
# data: tensor([[608.9421, 538.7261, 668.9713, 622.9227,   0.8318,   0.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# ...

# %%
# Now after making best Model of YOLOv5mu we start testing it

# %%
# %pwd
# Out:
# 'd:\\Projects\\Playfield_Vision'

# %%
model_location = 'models\\best_yolov5.pt'

best_model = YOLO(model_location)

results = best_model.predict(
    source='Input_Videos/B1606b0e6_1_17.mp4',
    save=True,
    project='output_videos',
    name='yolo_test2',
    exist_ok=True
)

print(results[0])
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) d:\Projects\Playfield_Vision\Input_Videos\B1606b0e6_1_17.mp4: 384x640 1 ball, 23 players, 1 referee, 43.2ms
# video 1/1 (frame 2/750) d:\Projects\Playfield_Vision\Input_Videos\B1606b0e6_1_17.mp4: 384x640 1 ball, 24 players, 1 referee, 23.7ms
# video 1/1 (frame 3/750) d:\Projects\Playfield_Vision\Input_Videos\B1606b0e6_1_17.mp4: 384x640 1 ball, 22 players, 1 referee, 25.2ms
# ...
